# %% [markdown]
# ## 💻 의뢰 : 고령화 인구를 고려한 추가 복지센터 고안 분석(추가 버전)
# ❕순서
# 1) 향후 20년 고령화 비율(%) 변화 (60세 기준)
# 2) 미래 복지센터 개수 (60세 기준)

# %%
#패키지 임포트
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# 한글처리
plt.rc('font', family='Malgun Gothic')
# '-' 문자 처리
plt.rc('axes', unicode_minus=False)

# %% [markdown]
# ### (1) 향후 20년 고령화 비율(%) 변화 (60세 기준)

# %%
#데이터 읽어오기
pop=pd.read_excel("전국_인구수.xlsx")

#행과 열 바꾸기
pop=pop.T

#첫번쨰 행 컬럼명으로 지정 후 첫번째 행 삭제
pop = pop.rename(columns=pop.iloc[0])
pop = pop.drop(pop.index[0])

# %%
#보고싶은 행만 저장
pop=pop.loc[['현재_고령인구비율','15년후_고령인구비율','20년후_고령인구비율'],:]
pop
# Out:
#                     전국
# 현재_고령인구비율    25.477386
# 15년후_고령인구비율  50.237833
# 20년후_고령인구비율  58.021497

# %% [markdown]
# - 시각화

# %% [markdown]
# (1) ver1 : 가로선 표시x

# %%
fig = plt.figure(figsize=(15,5)) ## 캔버스 생성
fig.set_facecolor('white') ## 캔버스 색상 설정
ax = fig.add_subplot() ## 그림 뼈대(프레임) 생성

year=['현재', '15년후', '20년후']

#ax.plot(x축, y축, marker='o', linewidth=선굵기 조정가능, color='색지정')
ax.plot(year,pop['전국'], marker='o', linewidth=3, color='limegreen') 

plt.title('향후 고령인구비율 변화(%) (60세 기준)',fontsize=13) ## 타이틀 설정
plt.show()

# %% [markdown]
# (2) ver2 : 50% 부분에 가로선 표시o
# -> 그래프의 이해를 돕기위해 50% 지점에 수평선을 추가해보았습니다!

# %%
fig = plt.figure(figsize=(15,5)) ## 캔버스 생성
fig.set_facecolor('white') ## 캔버스 색상 설정
ax = fig.add_subplot() ## 그림 뼈대(프레임) 생성

year=['현재', '15년후', '20년후']

#50% 지점에 가로 선 표시
plt.axhline(50.0, 0.0, 1.0, color='lightgray', linestyle='--', linewidth=2)

#ax.plot(x축, y축, marker='o', linewidth=선굵기 조정가능, color='색지정')
ax.plot(year,pop['전국'], marker='o', linewidth=3, color='limegreen') 

plt.title('향후 고령인구비율 변화(%) (60세 기준)',fontsize=13) ## 타이틀 설정
plt.show()

# %% [markdown]
# ### (2) 미래 복지센터 개수 (60세 기준)
# -> 50세~60세는 아직 생산활동을 하는 인구라고 생각해서 60세를 기준으로 그래프를 시각화하였습니다!
#
# -> 계산방법은 "추가복지센터_분석" 폴더의 "추가복지센터_계산방법.xlsx"을 참고해주세요!

# %%
#데이터 읽어오기
center=pd.read_excel("추가복지센터_숫자만.xlsx")

#행과열 바꾸기
center=center.T

#첫번쨰 행 컬럼명으로 지정 후 첫번째 행 삭제
center = center.rename(columns=center.iloc[0])
center = center.drop(center.index[0])

# %%
#보고싶은 컬럼만 저장
center=center[["요양시설개수"]]
center
# Out:
#       요양시설개수
# 현재    4057.0
# 5년후   5287.0
# 10년후  6670.0
# 15년후  7937.0
# 20년후  9167.0

# %%
#15년후, 20년후만 저장
center=center.loc[['현재','15년후','20년후'],:]
center
# Out:
#       요양시설개수
# 현재    4057.0
# 15년후  7937.0
# 20년후  9167.0

# %% [markdown]
# - 시각화

# %%
fig = plt.figure(figsize=(15,5)) ## 캔버스 생성
fig.set_facecolor('white') ## 캔버스 색상 설정
ax = fig.add_subplot() ## 그림 뼈대(프레임) 생성

year=['현재', '15년후', '20년후']
#ax.plot(x축, y축, marker='o', linewidth=선굵기 조정가능)
ax.plot(year,center['요양시설개수'], marker='o', linewidth=3, color='limegreen') 
 
plt.title('미래 복지센터 개수',fontsize=13) ## 타이틀 설정
plt.show()
