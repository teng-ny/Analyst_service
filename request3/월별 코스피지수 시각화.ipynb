# %% [markdown]
# ## 💻 월별 코스피지수 시각화

# %% [markdown]
# ### (1) 5개년(18-22년) 월별 코스피지수 시각화

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

#경고무시
import warnings
warnings.filterwarnings('ignore')
# 한글처리
plt.rc('font', family='Malgun Gothic')
# '-' 문자 처리
plt.rc('axes', unicode_minus=False)

# %%
#데이터 불러오기
kospi=pd.read_csv("result_month.csv", encoding='euc-kr')


#분석에 필요한 컬럼만 추출
kospi=kospi[['날짜', '종가']]
#컬럼명 변경
kospi.columns=['날짜', '코스피지수']


#데이터타입 datetime으로 변경
import datetime
kospi['날짜']=pd.to_datetime(kospi['날짜'])


#날짜에서 년도와 월을 분리
kospi['year'] = kospi['날짜'].dt.strftime("%Y")
kospi['month'] = kospi['날짜'].dt.strftime("%m")


#날짜 컬럼 "년도.월" 형식으로 변경
kospi['날짜']=kospi['year'] + '.' + kospi['month']


#시각화 시에 가독성을 위해 2018.01->18.02 형식으로 변경
kospi['날짜']=kospi['날짜'].str[2:]

# %%
kospi.head(3)
# Out:
#       날짜    코스피지수  year month
# 0  18.01  2566.46  2018    01
# 1  18.02  2427.36  2018    02
# 2  18.03  2445.85  2018    03

# %% [markdown]
# -> 변경된 것을 확인

# %% [markdown]
# - (1) 마커 표시ver

# %%
#x축으로 지정할 컬럼 'month'에 저장
month=kospi['날짜']

fig = plt.figure(figsize=(30,8)) ## 캔버스 생성
fig.set_facecolor('white') ## 캔버스 색상 설정
ax = fig.add_subplot() ## 그림 뼈대(프레임) 생성

#ax.plot(x축, y축, marker='o', linewidth=선굵기 조정가능)
ax.plot(month,kospi['코스피지수'], marker='o', linewidth=3) 
 
plt.title('18-22년도 월별 코스피지수 시각화',fontsize=20) ## 타이틀 설정
plt.show()

# %% [markdown]
# -> 그래프 이미지 저장해서 크게 보시면 x축 글자가 보이실 거에요!

# %% [markdown]
# - (2) 마커 표시x

# %%
#x축으로 지정할 컬럼 'month'에 저장
month=kospi['날짜']

fig = plt.figure(figsize=(30,8)) ## 캔버스 생성
fig.set_facecolor('white') ## 캔버스 색상 설정
ax = fig.add_subplot() ## 그림 뼈대(프레임) 생성

#ax.plot(x축, y축, marker='o')
ax.plot(month,kospi['코스피지수'], linewidth=3) 
 
plt.title('18-22년도 월별 코스피지수 시각화',fontsize=20) ## 타이틀 설정
plt.show()

# %% [markdown]
# ### (2) 3개년(19-21년) 월별 코스피지수 시각화

# %%
#19-21년도 데이터만 저장
kospi=kospi[(kospi['year']=='2019')|(kospi['year']=='2020')|(kospi['year']=='2021')]

# %%
kospi.tail()
# Out:
#        날짜    코스피지수  year month
# 43  21.08  3199.27  2021    08
# 44  21.09  3068.82  2021    09
# 45  21.10  2970.68  2021    10
# 46  21.11  2839.01  2021    11
# 47  21.12  2977.65  2021    12

# %% [markdown]
# - (1) 마커 표시ver

# %%
#x축으로 지정할 컬럼 'month'에 저장
month=kospi['날짜']

fig = plt.figure(figsize=(20,8)) ## 캔버스 생성
fig.set_facecolor('white') ## 캔버스 색상 설정
ax = fig.add_subplot() ## 그림 뼈대(프레임) 생성

#ax.plot(x축, y축, marker='o')
ax.plot(month,kospi['코스피지수'], marker='o', linewidth=3) 
 
plt.title('19-21년도 월별 코스피지수 시각화',fontsize=20) ## 타이틀 설정
plt.show()

# %%
#x축으로 지정할 컬럼 'month'에 저장
month=kospi['날짜']

fig = plt.figure(figsize=(20,8)) ## 캔버스 생성
fig.set_facecolor('white') ## 캔버스 색상 설정
ax = fig.add_subplot() ## 그림 뼈대(프레임) 생성

#ax.plot(x축, y축, marker='o')
ax.plot(month,kospi['코스피지수'], linewidth=3) 
 
plt.title('19-21년도 월별 코스피지수 시각화',fontsize=20) ## 타이틀 설정
plt.show()
